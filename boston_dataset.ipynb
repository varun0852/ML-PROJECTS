# %% [markdown]
# <a href="https://colab.research.google.com/github/varun0852/ML-PROJECTS/blob/main/boston_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats
import warnings
warnings.filterwarnings("ignore")
from statsmodels.stats.stattools import durbin_watson

# %%
# from google.colab import files
# uploaded = files.upload("")

# %%
df = pd.read_csv("Boston (2).csv")

# %%
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
df1 = df.drop("Unnamed: 0" , axis =1)

# %%
df1.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df1.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
x = df1.drop("medv" , axis = 1)
y = df1["medv"]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
x = np.array(x)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x,i) for i in range(x.shape[1])]
print(vif)
x = pd.DataFrame(x)
# Out:
#           vif
# 0    2.100373
# 1    2.844013
# 2   14.485758
# 3    1.152952
# 4   73.894947
# 5   77.948283
# 6   21.386850
# 7   14.699652
# 8   15.167725
# 9   61.227274
# 10  85.029547
# 11  20.104943
# 12  11.102025

# %%
x.columns
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
durbin_watson(y)
# Out:
# np.float64(0.0752829340704826)

# %%
# xtrain , xtest , ytrain , ytest = train_test_split(x,y,test_size = 0.2 , random_state = 1000)
xtrain , xtest , ytrain , ytest = train_test_split(x_vif,y,test_size = 0.2 , random_state = 1000)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (404, 3)
# (102, 3)
# (404,)
# (102,)

# %%
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier

# %%
# regr = LinearRegression()
regr = linear_model.LinearRegression()
# regr = DecisionTreeRegressor()
# regr = RandomForestRegressor()
# regr = GradientBoostingClassifier()

# %%
regr.fit(xtrain , ytrain)
# Out:
# LinearRegression()

# %%
regr.feature_importances_ # in linear model feature importances wont work cause linear model is not an embedded model
# Out:
# array([0.023985  , 0.00062491, 0.00349259, 0.00064185, 0.06217805,
#        0.57793989, 0.00866408, 0.08201041, 0.00096601, 0.01332607,
#        0.02165578, 0.02801587, 0.1764995 ])

# %%
df1.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
# ## Decision Tree cant use coefficient and intecept
# print("coefficients",regr.coef)
# print("intercept",regr.intercept)

# %%
# test predict
y_pred = regr.predict(xtest)
y_pred
# Out:
# array([21.28721939, 17.23169201, 15.50074937, 39.40324074, 25.38255596,
#        32.7359478 ,  9.17206841, 37.24330393, 18.05643006, 17.32398345,
#        34.83311938, 20.94984853, 28.67618178, 13.59105484, 25.635163  ,
#        24.05426189, 21.72643142, 13.17515619, 17.24475931, 30.52800124,
#        23.87596583, 16.08368633, 33.07338415, 19.31279942, 19.13055834,
#        13.20161493, 20.72158623, 17.48530444, 23.2681365 , 12.98218176,
#        35.21320262, 30.88533238, 20.40082529, 24.64557593, 18.61478937,
#        25.39486852, 25.03289866, 34.56747801, 27.82728449, 15.01888768,
#        21.04593597, 37.02676683,  8.86246192, 22.46800861, 22.93903849,
#        28.24245417, 26.7727513 , 17.54255681, 19.03295403, 24.33920351,
#        23.48354875, 26.84361857, 15.64217399, 17.97463834, 29.34531385,
#        18.79531642, 23.07067877, 12.63711587, 17.12150905, 17.36958789,
#        15.72068021, 25.31760755, 27.77053501, 11.62690437, 29.25159282,
# ...

# %%
print(r2_score(ytest , y_pred))# coefficient and determination
print(mean_squared_error(ytest , y_pred))
# print(mean_absolute_error(ytest , y_pred))
# Out:
# 0.30993838768644244
# 0.00031249868287013736

# %%
y_pred_train = regr.predict(xtrain)
# y_pred_train

# %%
print(r2_score(ytrain , y_pred_train))# coefficient and determination
print(mean_squared_error(ytrain , y_pred_train))
# print(mean_absolute_error(ytrain , y_pred_train)
# Out:
# 0.7484272373846235
# 21.171852282225267

# %% [markdown]
# ## Accuracy Improving **Technique**

# %%
x_vif = df1.iloc[:,[0,1,3]]
x_vif
# Out:
#         crim    zn  chas
# 0    0.00632  18.0     0
# 1    0.02731   0.0     0
# 2    0.02729   0.0     0
# 3    0.03237   0.0     0
# 4    0.06905   0.0     0
# ..       ...   ...   ...
# 501  0.06263   0.0     0
# 502  0.04527   0.0     0
# 503  0.06076   0.0     0
# 504  0.10959   0.0     0
# 505  0.04741   0.0     0
#
# [506 rows x 3 columns]

# %%
bost_n = Normalizer().fit_transform(df1)
bost_n = pd.DataFrame(bost_n, columns = df1.columns)
bost_n
# Out:
#          crim        zn     indus  chas       nox        rm       age  \
# 0    0.000013  0.035955  0.004614   0.0  0.001075  0.013134  0.130238
# 1    0.000058  0.000000  0.014961   0.0  0.000992  0.013588  0.166966
# 2    0.000058  0.000000  0.015133   0.0  0.001004  0.015379  0.130778
# 3    0.000071  0.000000  0.004772   0.0  0.001003  0.015319  0.100257
# 4    0.000150  0.000000  0.004740   0.0  0.000996  0.015539  0.117842
# ..        ...       ...       ...   ...       ...       ...       ...
# 501  0.000129  0.000000  0.024652   0.0  0.001184  0.013624  0.142789
# 502  0.000093  0.000000  0.024399   0.0  0.001172  0.012517  0.156866
# 503  0.000124  0.000000  0.024272   0.0  0.001166  0.014193  0.185144
# 504  0.000224  0.000000  0.024430   0.0  0.001173  0.013913  0.182867
# 505  0.000097  0.000000  0.024382   0.0  0.001171  0.012324  0.165133
#
#           dis       rad       tax   ptratio     black     lstat      medv
# ...

# %%
X = bost_n.drop("medv" , axis = 1)
Y = bost_n["medv"]

# %%
bost_n.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.205217  0.245886 -0.063494 -0.080784 -0.493759  0.087648
# zn      -0.205217  1.000000 -0.521216 -0.019292 -0.297702  0.385258 -0.481557
# indus    0.245886 -0.521216  1.000000  0.081398  0.415608 -0.449485  0.447608
# chas    -0.063494 -0.019292  0.081398  1.000000  0.146826  0.102897  0.114986
# nox     -0.080784 -0.297702  0.415608  0.146826  1.000000  0.244445  0.600458
# rm      -0.493759  0.385258 -0.449485  0.102897  0.244445  1.000000 -0.040462
# age      0.087648 -0.481557  0.447608  0.114986  0.600458 -0.040462  1.000000
# dis     -0.418596  0.643707 -0.627394 -0.052137 -0.260137  0.579425 -0.493855
# rad      0.614210 -0.313493  0.282100 -0.039650 -0.210888 -0.700785  0.026088
# tax      0.549562 -0.329060  0.458148 -0.075738 -0.117253 -0.798786  0.081326
# ptratio -0.375030  0.030620 -0.195065 -0.017185  0.204856  0.585528  0.048708
# ...

# %%
Xtrain , Xtest , Ytrain , Ytest = train_test_split(X,Y,test_size = 0.2 , random_state = 1000)

# %%
print(Xtrain.shape)
print(Xtest.shape)
print(Ytrain.shape)
print(Ytest.shape)
# Out:
# (404, 13)
# (102, 13)
# (404,)
# (102,)

# %%
regr.fit(Xtrain , Ytrain)
# Out:
# LinearRegression()

# %%
# regr.feature_importances_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3300054125.py in <cell line: 0>()
# ----> 1 regr.feature_importances_
#
# AttributeError: 'LinearRegression' object has no attribute 'feature_importances_'

# %%
bost_n.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
# test predict
y_pred1 = regr.predict(xtest)
y_pred1
# Out:
# array([-8.08071092e+00, -9.17464139e+00, -5.21898023e-01,  2.27852189e+01,
#        -4.52460240e+00,  1.75742688e+01, -1.80411139e+01,  1.95125744e+01,
#        -3.63822209e-03, -2.27328558e-01,  2.13213997e+01,  1.38741618e+00,
#         1.11725004e+01, -9.18733201e+00,  3.20935083e+00,  8.66317588e+00,
#         5.95802426e+00, -1.06245142e+01, -6.51687053e+00,  1.44417492e+01,
#         1.03397040e+01, -3.41679025e+00,  1.48946859e+01, -5.42448358e+00,
#        -1.04033648e+01, -3.91501682e+00,  6.44980265e-01, -1.16976452e+00,
#        -6.13679997e+00, -5.38814506e+00,  2.29210222e+01,  9.74692056e+00,
#        -7.04515444e+00,  8.82964397e+00, -7.01116887e+00,  6.38456555e+00,
#         6.59807386e+00,  2.04068367e+01,  1.65382959e+01, -2.31655405e+00,
#        -6.64672144e-01,  2.23800395e+01, -1.80724197e+01,  5.74189887e+00,
#         4.04401952e+00,  9.63054946e+00,  1.34246392e+01, -8.86417579e+00,
# ...

# %%
# test predict
y_pred1 = regr.predict(Xtest)
y_pred1
# Out:
# array([0.02522539, 0.02195398, 0.03459968, 0.08339961, 0.02976166,
#        0.07490908, 0.01301273, 0.07207177, 0.03560907, 0.03517199,
#        0.08244352, 0.03810436, 0.0600562 , 0.02206949, 0.04108746,
#        0.05447046, 0.04915729, 0.01985688, 0.02606235, 0.06540807,
#        0.05910747, 0.02965928, 0.06647794, 0.02852925, 0.02146294,
#        0.02673686, 0.03677119, 0.03324004, 0.02778728, 0.02519294,
#        0.08722506, 0.05408366, 0.02663548, 0.05523601, 0.02669048,
#        0.04826156, 0.04921246, 0.07773569, 0.06748355, 0.03094312,
#        0.03442797, 0.08030921, 0.01256843, 0.04832345, 0.04356839,
#        0.05458754, 0.0648008 , 0.0243213 , 0.02617291, 0.04967808,
#        0.04798665, 0.04591485, 0.0268979 , 0.02525614, 0.05382666,
#        0.0409859 , 0.0451918 , 0.01136555, 0.02489408, 0.03404613,
#        0.01871606, 0.04729907, 0.0569582 , 0.01853475, 0.05669915,
#        0.06225848, 0.02952066, 0.02942691, 0.05899655, 0.02735578,
# ...

# %%
print(r2_score(Ytest , y_pred1))# coefficient and determination
print(mean_squared_error(Ytest , y_pred1))
# print(mean_absolute_error(ytest , y_pred))
# Out:
# 0.8648669514123365
# 6.119583953422802e-05

# %%
y_pred_train = regr.predict(Xtrain)
# y_pred_train

# %%
print(r2_score(Ytrain , y_pred_train))# coefficient and determination
print(mean_squared_error(Ytrain , y_pred_train))
# print(mean_absolute_error(ytrain , y_pred_train)
# Out:
# 1.0
# 0.0
